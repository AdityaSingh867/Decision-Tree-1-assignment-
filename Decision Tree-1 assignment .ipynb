# %% [markdown]
# Q1. Describe the decision tree classifier algorithm and how it works to make predictions.

# %% [markdown]
# Decision tree classifire algorithm is a machine learning algorithm that uses to make a decision tree to make predictions.
#
# The algorithm works by recursively splitting the data into subsets based on the most significant feature at each node of the tree.

# %% [markdown]
# Q2. Provide a step-by-step explanation of the mathematical intuition behind decision tree classification.

# %% [markdown]
# - First a fall we choose a feature to start making the decision tree
# - Than we do gini impurity for checking the pure and impure soplit
# - for choosing the best feature for making the decision tree we use Information gain , Formula of information gain

# %% [markdown]
# ![WhatsApp Image 2023-05-19 at 00.18.49.jpeg](attachment:6e2335aa-fce6-4e03-99ea-b46d055a1b2c.jpeg)

# %% [markdown]
# H(s) = Entropy of the root node

# %% [markdown]
# EXAMPLE ::::

# %% [markdown]
# ![WhatsApp Image 2023-05-19 at 00.23.52.jpeg](attachment:a7a31f2c-a014-4ecd-a5d3-98ed586549bd.jpeg)

# %% [markdown]
# Entropy and Gini impurity these are the way to creat decision tree , Wjen the size of our dataset is not such a big like 1k , 10k , 20k , than we use Entropy , but if dataset is so big like 100k , 200k , 150k we use Gini impurity , because Entropy is a time taking , but Gini impurity is much faster than Entropy.

# %% [markdown]
# Q3. Explain how a decision tree classifier can be used to solve a binary classification problem.

# %% [markdown]
# __decision tree For binary classification problem__
# - For explaning the decision tree for binary problem i take a data

# %% [markdown]
# ![Annotation 2023-05-19 003615.png](attachment:40188c54-6673-46b6-97cf-494c95f0ee70.png)

# %% [markdown]
# __In this data there is many feature like Outlook , Temperature , Humidity , Wind__
# - For chossing the best feature for decision we use the information gain
# - The best Feature is Outlook
# - In the outlook there is three different type of weather Sunny , overcast , Rain
# - we make one node with three split

# %% [markdown]
# ![WhatsApp Image 2023-05-19 at 00.46.19.jpeg](attachment:e1bb45f0-cd61-4f5d-96ac-e8cf6ed24dcc.jpeg)

# %% [markdown]
# - there is 2(Yes) and 3(No) for Sunny day in Outlook Feature
# - there is 4(Yes) and 0(No) for Overcast day in Outlook Feature , these is leaf node because there is 0(no)
# - there is 3(Yes) and 2(No) for Rain day in Outlook Feature

# %% [markdown]
# Q4. Discuss the geometric intuition behind decision tree classification and how it can be used to make
# predictions.

# %% [markdown]
# geometric intuition of the decision tree
# - we choose the feature from dataset
# - make node of that
# - split it
# - than the split is called node
# - than further split it on the basis of dataset
# - This process continues until a stopping criterion is met, such as reaching a maximum depth or a minimum number of data points in a region.

# %% [markdown]
# Q5. Define the confusion matrix and describe how it can be used to evaluate the performance of a
# classification model.

# %% [markdown]
# Confusion matrix is a table that is used to define the performance of the classification of the algorithm
#
# how it can be used to evaluate the performance of a classification model :
#
#     For the use of Confusion matrix we se that how many TP , TN , FP , FN is here for this we evaluate the performance of a classification model.

# %% [markdown]
# Q6. Provide an example of a confusion matrix and explain how precision, recall, and F1 score can be
# calculated from it.

# %% [markdown]
#     __________________________________________________
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -          TP(89)       -         FN(45)         -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     __________________________________________________
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -          FP(32)       -        TN(67)          -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -                       -                        -
#     -_________________________________________________

# %% [markdown]
# Precision = TruePositives / (TruePositives + FalsePositives)
# - TruePositives = 89
# - FalsePositives = 32
# - Precision = 0.73553719008

# %% [markdown]
# recall = TruePositives / (TruePositives + FalseNegative)
# - TruePositives = 89
# - FalseNegative = 45
# - recall = 0.66417910447

# %% [markdown]
# F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
# - Precision = 0.73553719008
# - Recall = 0.66417910447
# - F1 Score = 0.6976744186

# %% [markdown]
# Q7. Discuss the importance of choosing an appropriate evaluation metric for a classification problem and
# explain how this can be done.

# %% [markdown]
# selecting an appropriate evaluation metric is essential to accurately assess the performance of a classification model. It ensures that the evaluation aligns with the problem's goals, accounts for class imbalances, considers cost considerations, provides interpretability, and guides decision-making processes effectively.

# %% [markdown]
# Q8. Provide an example of a classification problem where precision is the most important metric, and
# explain why.

# %% [markdown]
# __This is the best example for explaning the precision__
#
# EMAIL
#
# In email we have a spam folder , all the spam email gose in spam folder and all the important email are gose in inbox , but if some inbox email gose in spam folder so this is not good for us , this type of issue called Precision.

# %% [markdown]
# Q9. Provide an example of a classification problem where recall is the most important metric, and explain
# why.

# %% [markdown]
# __This is the best example for explaning the precision__
#
# Diabetes
#
# If there is a machine for check Diabetes , you check the Diabetes and mechine says you are non-Diabetic , But in reality you are Diabetic so this is realy bad for our health , mechine says you are non-Diabetic so , you did not go to doctor for your Diabetes check up so , this is realy so bad for our health , This type of promlem in mechine is called recall
